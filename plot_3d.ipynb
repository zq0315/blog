# %% [markdown]
# <a href="https://colab.research.google.com/github/zq0315/blog/blob/master/plot_3d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 创建数据
x = np.linspace(-0.01, 0.01, 100)
y = np.linspace(-0.01, 0.01, 100)
x, y = np.meshgrid(x, y)
fx = 1/(1 + np.exp(-(0.02*x + 0.01*y)))
z = fx
#sigmod函数的倒数为fx(1-fx)
z = fx*(1-fx)
# 创建图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制三维曲面
ax.plot_surface(x, y, z, cmap='viridis')

# 绘制三维线框图（可选）
ax.plot_wireframe(x, y, z, color='k', alpha=0.3)

# 设置标签
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

# 显示图形
plt.show()
